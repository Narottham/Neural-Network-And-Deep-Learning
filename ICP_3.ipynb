100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.5711 - acc: 0.7344
# Epoch 59/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.5905 - acc: 0.7153
# Epoch 60/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5804 - acc: 0.7274
# Epoch 61/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5671 - acc: 0.7396
# Epoch 62/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5770 - acc: 0.7153
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5760 - acc: 0.7257
# Epoch 64/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6522 - acc: 0.6840
# Epoch 65/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5730 - acc: 0.7205
# Epoch 66/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5809 - acc: 0.7274
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6032 - acc: 0.7049
# Epoch 68/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5715 - acc: 0.7101
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5952 - acc: 0.7135
# Epoch 70/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5780 - acc: 0.7326
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5880 - acc: 0.6997
# Epoch 72/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5741 - acc: 0.7222
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5674 - acc: 0.7118
# Epoch 74/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5612 - acc: 0.7378
# Epoch 75/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5534 - acc: 0.7344
# Epoch 76/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5672 - acc: 0.7240
# Epoch 77/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5572 - acc: 0.7222
# Epoch 78/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5555 - acc: 0.7378
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5704 - acc: 0.7188
# Epoch 80/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5596 - acc: 0.7309
# Epoch 81/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5577 - acc: 0.7378
# Epoch 82/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5820 - acc: 0.7170
# Epoch 83/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5681 - acc: 0.7326
# Epoch 84/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5642 - acc: 0.7483
# Epoch 85/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5560 - acc: 0.7344
# Epoch 86/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5620 - acc: 0.7413
# Epoch 87/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5629 - acc: 0.7413
# Epoch 88/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5550 - acc: 0.7361
# Epoch 89/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5782 - acc: 0.7240
# Epoch 90/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5614 - acc: 0.7031
# Epoch 91/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5436 - acc: 0.7396
# Epoch 92/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5424 - acc: 0.7448
# Epoch 93/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5534 - acc: 0.7344
# Epoch 94/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5438 - acc: 0.7465
# Epoch 95/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5461 - acc: 0.7500
# Epoch 96/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5445 - acc: 0.7431
# Epoch 97/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5513 - acc: 0.7413
# Epoch 98/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5427 - acc: 0.7361
# Epoch 99/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5526 - acc: 0.7448
# Epoch 100/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5604 - acc: 0.7431
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                180
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 201 (804.00 Byte)
# Trainable params: 201 (804.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6105 - acc: 0.6823
# [0.6105337738990784, 0.6822916865348816]

# %%
#Add more Dense layers to the existing code and check how the accuracy changes

import keras
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np



dataset = pd.read_csv(path_to_csv, header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(15, activation='relu'))               # Second hidden layer
my_first_nn.add(Dense(10, activation='relu'))               # Third hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 4ms/step - loss: 8.0012 - acc: 0.6528
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 2.6467 - acc: 0.5538
# Epoch 3/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.4422 - acc: 0.5729
# Epoch 4/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8849 - acc: 0.5712
# Epoch 5/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.8007 - acc: 0.6319
# Epoch 6/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0
100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5381 - acc: 0.7396
# Epoch 77/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5413 - acc: 0.7361
# Epoch 78/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5609 - acc: 0.7188
# Epoch 79/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5466 - acc: 0.7465
# Epoch 80/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5340 - acc: 0.7378
# Epoch 81/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5589 - acc: 0.7135
# Epoch 82/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5562 - acc: 0.7500
# Epoch 83/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5436 - acc: 0.7361
# Epoch 84/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5595 - acc: 0.7135
# Epoch 85/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5488 - acc: 0.7257
# Epoch 86/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5413 - acc: 0.7240
# Epoch 87/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5442 - acc: 0.7361
# Epoch 88/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5371 - acc: 0.7361
# Epoch 89/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5436 - acc: 0.7361
# Epoch 90/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5510 - acc: 0.7344
# Epoch 91/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5449 - acc: 0.7274
# Epoch 92/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5323 - acc: 0.7361
# Epoch 93/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5428 - acc: 0.7361
# Epoch 94/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5362 - acc: 0.7413
# Epoch 95/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5432 - acc: 0.7465
# Epoch 96/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5601 - acc: 0.7274
# Epoch 97/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5550 - acc: 0.7292
# Epoch 98/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5695 - acc: 0.7135
# Epoch 99/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5543 - acc: 0.7431
# Epoch 100/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5323 - acc: 0.7448
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 20)                180
#
#  dense_3 (Dense)             (None, 15)                315
#
#  dense_4 (Dense)             (None, 10)                160
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 666 (2.60 KB)
# Trainable params: 666 (2.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5704 - acc: 0.7292
# [0.5703728199005127, 0.7291666865348816]

# %%
path_to_csv = '/content/gdrive/My Drive/breastcancer.csv'

# %%
#Change the data source to Breast Cancer dataset * available in the source code folder and make required changes. Report accuracy of the model.

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense

# Load the breast cancer dataset
data = load_breast_cancer()

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target,test_size=0.25, random_state=87)

# Normalize data
sc = StandardScaler()
X_train_norm = sc.fit_transform(X_train)
X_test_norm = sc.transform(X_test)

# Create model
np.random.seed(155)
my_first_nn = Sequential() # create model
# Adjust input_dim to match the number of features in breast cancer dataset
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer
my_first_nn.add(Dense(15, activation='relu'))               # Second hidden layer
my_first_nn.add(Dense(10, activation='relu'))               # Third hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
# Use the correct variable name for the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
my_first_nn.fit(X_train_norm, y_train, epochs=100, initial_epoch=0)

# Evaluate model on testing set
loss, accuracy = my_first_nn.evaluate(X_test_norm, y_test)
print(my_first_nn.summary())
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 5ms/step - loss: 0.7540 - accuracy: 0.3380
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.4531
# Epoch 3/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6399 - accuracy: 0.7465
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5721 - accuracy: 0.8944
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4877 - accuracy: 0.9390
# Epoch 6/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3871 - accuracy: 0.9531
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2876 - accuracy: 0.9554
# Epoch 8/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2106 - accuracy: 0.9624
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1617 - accuracy: 0.9648
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1322 - accuracy: 0.9648
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 0.9718
# Epoch 12/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9765
# Epoch 13/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0893 - accuracy: 0.9765
# Epoch 14/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9765
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9742
# Epoch 16/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 0.9789
# Epoch 17/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9836
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 0.9836
# Epoch 19/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0559 - accuracy: 0.9883
# Epoch 20/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0526 - accuracy: 0.9859
# Epoch 21/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9859
# Epoch 22/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0464 - accuracy: 0.9883
# Epoch 23/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9859
# Epoch 24/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0408 - accuracy: 0.9859
# Epoch 25/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0384 - accuracy: 0.9883
# Epoch 26/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0367 - accuracy: 0.9883
# Epoch 27/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0341 - accuracy: 0.9883
# Epoch 28/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0325 - accuracy: 0.9883
# Epoch 29/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0301 - accuracy: 0.9906
# Epoch 30/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0289 - accuracy: 0.9930
# Epoch 31/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0272 - accuracy: 0.9930
# Epoch 32/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0255 - accuracy: 0.9930
# Epoch 33/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0244 - accuracy: 0.9906
# Epoch 34/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0233 - accuracy: 0.9906
# Epoch 35/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0224 - accuracy: 0.9930
# Epoch 36/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0213 - accuracy: 0.9930
# Epoch 37/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0197 - accuracy: 0.9930
# Epoch 38/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0188 - accuracy: 0.9953
# Epoch 39/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0180 - accuracy: 0.9977
# Epoch 40/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0170 - accuracy: 0.9977
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.9977
# Epoch 42/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 0.9977
# Epoch 43/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0147 - accuracy: 0.9977
# Epoch 44/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9977
# Epoch 45/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0129 - accuracy: 0.9977
# Epoch 46/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9977
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 0.9953
# Epoch 48/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9977
# Epoch 49/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9977
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9977
# Epoch 51/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9977
# Epoch 52/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0088 - accuracy: 0.9977
# Epoch 53/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 54/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 55/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 56/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 58/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 59/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 60/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 61/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 62/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 64/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 65/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 66/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 67/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 68/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 69/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 70/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 71/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 72/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 73/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 74/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 76/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 77/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 80/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 81/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 82/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 83/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 84/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 85/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 86/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 87/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 88/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 89/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 90/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 93/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 94/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 95/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 96/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 97/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 98/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 9.8273e-04 - accuracy: 1.0000
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 9.6709e-04 - accuracy: 1.0000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4963 - accuracy: 0.9580
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 20)                620
#
#  dense_7 (Dense)             (None, 15)                315
#
#  dense_8 (Dense)             (None, 10)                160
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1106 (4.32 KB)
# Trainable params: 1106 (4.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Loss: 0.49631863832473755
# Accuracy: 0.9580419659614563

# %%
#Change the data source to Breast Cancer dataset * available in the source code folder and make required changes. Report accuracy of the model.

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense

# Load the breast cancer dataset
data = load_breast_cancer()

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target,test_size=0.25, random_state=87)

# Normalize data
sc = StandardScaler()
X_train_norm = sc.fit_transform(X_train)
X_test_norm = sc.transform(X_test)

# Create model
np.random.seed(155)
my_first_nn = Sequential() # create model
# Adjust input_dim to match the number of features in breast cancer dataset
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer
my_first_nn.add(Dense(15, activation='relu'))               # Second hidden layer
my_first_nn.add(Dense(10, activation='relu'))               # Third hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
# Use the correct variable name for the model
my_first_nn.compile(loss='binary_crossentropy')

# %%
# Normalize the data before feeding the data to the model and check how the normalization change your accuracy


from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# loading dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn_model = Sequential() # creating model
my_nn_model.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn_model.add(Dense(1, activation='sigmoid')) # output layer
my_nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn_model.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn_model.summary())
print(my_nn_model.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 0.9954 - acc: 0.7981
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6139 - acc: 0.8380
# Epoch 3/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0
20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0234 - accuracy: 0.9922 - val_loss: 0.0791 - val_accuracy: 0.9812
# Epoch 12/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.0742 - val_accuracy: 0.9821
# Epoch 13/20
# 469/469 [==============================] - 16s 35ms/step - loss: 0.0209 - accuracy: 0.9926 - val_loss: 0.0801 - val_accuracy: 0.9808
# Epoch 14/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 0.0767 - val_accuracy: 0.9820
# Epoch 15/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0165 - accuracy: 0.9941 - val_loss: 0.0786 - val_accuracy: 0.9826
# Epoch 16/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0174 - accuracy: 0.9940 - val_loss: 0.0732 - val_accuracy: 0.9833
# Epoch 17/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0829 - val_accuracy: 0.9818
# Epoch 18/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0163 - accuracy: 0.9949 - val_loss: 0.0693 - val_accuracy: 0.9833
# Epoch 19/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0830 - val_accuracy: 0.9808
# Epoch 20/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.0757 - val_accuracy: 0.9844

# %%
#  Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# loading mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# converting class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# to create a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# to train the model
model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
          epochs=20, batch_size=128)

# to plot one of the images in the test data
plt.imshow(x_test[0], cmap='gray')
plt.show()

# making a prediction on the image using the trained model
prediction = model.predict(x_test[0].reshape(1, -1))
print('Model prediction:', np.argmax(prediction))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 12s 24ms/step - loss: 0.2514 - accuracy: 0.9249 - val_loss: 0.1134 - val_accuracy: 0.9637
# Epoch 2/20
# 469/469 [==============================] - 12s 25ms/step - loss: 0.1031 - accuracy: 0.9675 - val_loss: 0.0888 - val_accuracy: 0.9694
# Epoch 3/20
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0724 - accuracy: 0.9772 - val_loss: 0.0691 - val_accuracy: 0.9786
# Epoch 4/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0554 - accuracy: 0.9822 - val_loss: 0.0684 - val_accuracy: 0.9786
# Epoch 5/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0468 - accuracy: 0.9844 - val_loss: 0.0629 - val_accuracy: 0.9810
# Epoch 6/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0405 - accuracy: 0.9871 - val_loss: 0.0686 - val_accuracy: 0.9786
# Epoch 7/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.0601 - val_accuracy: 0.9820
# Epoch 8/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0309 - accuracy: 0.9897 - val_loss: 0.0628 - val_accuracy: 0.9828
# Epoch 9/20
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 0.0709 - val_accuracy: 0.9813
# Epoch 10/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.0674 - val_accuracy: 0.9803
# Epoch 11/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 0.0669 - val_accuracy: 0.9822
# Epoch 12/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0725 - val_accuracy: 0.9828
# Epoch 13/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0716 - val_accuracy: 0.9833
# Epoch 14/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0186 - accuracy: 0.9933 - val_loss: 0.0835 - val_accuracy: 0.9795
# Epoch 15/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0765 - val_accuracy: 0.9814
# Epoch 16/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.0791 - val_accuracy: 0.9818
# Epoch 17/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0802 - val_accuracy: 0.9816
# Epoch 18/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.0788 - val_accuracy: 0.9834
# Epoch 19/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.0811 - val_accuracy: 0.9813
# Epoch 20/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0169 - accuracy: 0.9943 - val_loss: 0.0753 - val_accuracy: 0.9837
# 1/1 [==============================] - 0s 132ms/step
# Model prediction: 7

# %%
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0682, Test accuracy: 0.9804
# 1 hidden layer with sigmoid - Test loss: 0.0598, Test accuracy: 0.9818
# 2 hidden layers with tanh - Test loss: 0.0640, Test accuracy: 0.9834
# 2 hidden layers with sigmoid - Test loss: 0.0644, Test accuracy: 0.9817

# %%
# Run the same code without scaling the images and check the performance
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1753, Test accuracy: 0.9462
# 1 hidden layer with sigmoid - Test loss: 0.1576, Test accuracy: 0.9519
# 2 hidden layers with tanh - Test loss: 0.1363, Test accuracy: 0.9586
# 2 hidden layers with sigmoid - Test loss: 0.1089, Test accuracy: 0.9665
